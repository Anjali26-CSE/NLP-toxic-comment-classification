# %% [markdown]
# <a href="https://colab.research.google.com/github/Anjali26-CSE/NLP-toxic-comment-classification/blob/main/Untitled4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import files
Uploaded = files.upload()
# Out:
#      <input type="file" id="files-fce420f2-c0df-481e-a2e8-c830c1918799" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-fce420f2-c0df-481e-a2e8-c830c1918799">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd
df  = pd.read_excel("Toxic Comment Moderation Dataset.xlsx")
df.drop_duplicates(inplace=True)
df.fillna(0, inplace=True)
df.columns = df.columns.str.lower()

# %%
df.head()
# Out:
#    comment_id user_id                                       comment_text  \
# 0           1    U026                  This was very helpful, thank you.
# 1           2    U040  I tried this and it works, thanks for the deta...
# 2           3    U028                           this almost work but bug
# 3           4    U033  Helpful article, though screenshots would make...
# 4           5   U1225         this lowkey taught me more than my teacher
#
#    is_toxic toxicity_type  sentiment_score date_posted  platform  \
# 0     False          none            0.191  2023-10-02   YouTube
# 1     False          none            0.306  2024-04-29  Facebook
# 2     False          none            0.412  2024-06-06    Reddit
# 3     False          none            0.529  2022-01-25  Facebook
# 4     False          none            0.900  2024-11-22   Youtube
#
#    label_verified moderation_action
# 0           False          approved
# 1            True          approved
# ...

# %%
df.isnull().sum()
# Out:
# comment_id           0
# user_id              0
# comment_text         0
# is_toxic             0
# toxicity_type        0
# sentiment_score      0
# date_posted          0
# platform             0
# label_verified       0
# moderation_action    0
# dtype: int64

# %%
df.dropna(inplace=True)

# %%
df.drop_duplicates(inplace=True)

# %%
df.columns = df.columns.str.lower()

# %%
df.drop('comment_text', axis=1, inplace=True)

# %%
import re
df['comment_text']=df['comment_text'].str.lower()
df['comment_text']=df['comment_text'].apply (lambda x:re.sub(r'[^a-zA-Z ]','',x))
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.12/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3804         try:
# -> 3805             return self._engine.get_loc(casted_key)
#    3806         except KeyError as err:
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'comment_text'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# /tmp/ipython-input-2965333398.py in <cell line: 0>()
#       1 import re
# ...

# %%
df.to_csv("cleaned_data.csv",index=False)

# %%
files.download("cleaned_data.csv")
